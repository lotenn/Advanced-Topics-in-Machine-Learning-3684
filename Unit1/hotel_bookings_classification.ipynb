# %% [markdown]
# # <center> Unit 1 - Ensemble Learning practical work
# ## <center> Hotel booking demand Classification

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import ConfusionMatrixDisplay, precision_recall_fscore_support
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/hotel_bookings.csv')
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            119390.000000         119390.000000  119390.000000
# mean                  0.927599              2.500302       1.856403
# std                   0.998613              1.908286       0.579261
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  19.000000             50.000000      55.000000
#
#             children         babies  is_repeated_guest  \
# count  119386.000000  119390.000000      119390.000000
# mean        0.103890       0.007949           0.031912
# std         0.398561       0.097436           0.175767
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           119390.000000                   119390.000000
# mean                 0.087118                        0.137097
# std                  0.844336                        1.497437
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes          agent      company  days_in_waiting_list  \
# count    119390.000000  103050.000000  6797.000000         119390.000000
# mean          0.221124      86.693382   189.266735              2.321149
# std           0.652306     110.774548   131.655015             17.594721
# min           0.000000       1.000000     6.000000              0.000000
# 25%           0.000000       9.000000    62.000000              0.000000
# 50%           0.000000      14.000000   179.000000              0.000000
# 75%           0.000000     229.000000   270.000000              0.000000
# max          21.000000     535.000000   543.000000            391.000000
#
#                  adr  required_car_parking_spaces  total_of_special_requests
# count  119390.000000                119390.000000              119390.000000
# mean      101.831122                     0.062518                   0.571363
# std        50.535790                     0.245291                   0.792798
# min        -6.380000                     0.000000                   0.000000
# 25%        69.290000                     0.000000                   0.000000
# 50%        94.575000                     0.000000                   0.000000
# 75%       126.000000                     0.000000                   1.000000
# max      5400.000000                     8.000000                   5.000000

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# deposit_type                       object
# agent                             float64
# company                           float64
# days_in_waiting_list                int64
# customer_type                      object
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# reservation_status                 object
# reservation_status_date            object
# dtype: object

# %%
columns_mapping = {
    'hotel': '(H1 = Resort Hotel or H2 = City Hotel)',
    'is_canceled': 'Value indicating if the booking was canceled (1) or not (0)',
    'lead_time': 'Number of days that elapsed between the entering date of the booking into the PMS and the arrival date',
    'arrival_date_year': 'Year of arrival date',
    'arrival_date_month': 'Month of arrival date',
    'arrival_date_week_number': 'Week number of year for arrival date',
    'arrival_date_day_of_month': 'Day of arrival date',
    'stays_in_weekend_nights': 'Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel',
    'stays_in_week_nights': 'Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel',
    'adults': 'Number of adults',
    'children': 'Number of children',
    'babies': 'Number of babies',
    'meal': 'Type of meal booked. Categories are presented in standard hospitality meal packages:\nUndefined/SC – no meal package; BB – Bed & Breakfast;\nHB – Half board (breakfast and one other meal – usually dinner);\nFB – Full board (breakfast, lunch and dinner)',
    'country': 'Country of origin. Categories are represented in the ISO 3155–3:2013 format',
    'market_segment': 'Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”',
    'distribution_channel': 'Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”',
    'is_repeated_guest': 'Value indicating if the booking name was from a repeated guest (1) or not (0)',
    'previous_cancellations': 'Number of previous bookings that were cancelled by the customer prior to the current booking',
    'previous_bookings_not_canceled': 'Number of previous bookings not cancelled by the customer prior to the current booking',
    'reserved_room_type': 'Code of room type reserved. Code is presented instead of designation for anonymity reasons.',
    'assigned_room_type': 'Code for the type of room assigned to the booking.\nSometimes the assigned room type differs from the reserved room type due to hotel operation reasons\n(e.g. overbooking) or by customer request.\nCode is presented instead of designation for anonymity reasons.',
    'booking_changes': 'Number of changes/amendments made to the booking\nfrom the moment the booking was entered on the PMS until the moment of check-in or cancellation',
    'deposit_type': 'Indication on if the customer made a deposit to guarantee the booking.\nThis variable can assume three categories:\nNo Deposit – no deposit was made;\nNon Refund – a deposit was made in the value of the total stay cost;\nRefundable – a deposit was made with a value under the total cost of stay.',
    'agent': 'ID of the travel agency that made the booking',
    'company': 'ID of the company/entity that made the booking or responsible for paying the booking.\nID is presented instead of designation for anonymity reasons',
    'days_in_waiting_list': 'Number of days the booking was in the waiting list before it was confirmed to the customer',
    'customer_type': 'Type of booking, assuming one of four categories:\nContract - when the booking has an allotment or other type of contract associated to it;\nGroup – when the booking is associated to a group;\nTransient – when the booking is not part of a group or contract, and is not associated to other transient booking;\nTransient-party – when the booking is transient, but is associated to at least other transient booking',
    'adr': 'Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights',
    'required_car_parking_spaces': 'Number of car parking spaces required by the customer',
    'total_of_special_requests': 'Number of special requests made by the customer (e.g. twin bed or high floor)',
    'reservation_status': 'Reservation last status, assuming one of three categories:\nCanceled – booking was canceled by the customer;\nCheck-Out – customer has checked in but already departed;\nNo-Show – customer did not check-in and did inform the hotel of the reason why',
    'reservation_status_date': 'Date at which the last status was set.\nThis variable can be used in conjunction with the ReservationStatus to understand\nwhen was the booking canceled or when did the customer checked-out of the hotel'
}

# %% [markdown]
# Look for missing values and omit the containing rows

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %% [markdown]
# We see that `company` has many missing values, so we drop the column entirely
# We replace agent `null` values with `0` to represent `null`
# We set the missing countries as a `XXX` code
# We drop the rows with missing `children` values

# %%
clean_df = df.fillna(value={'agent': 0, 'country': 'XXX'}).drop(columns='company')
clean_df = clean_df.dropna(axis=0, subset=['children'])
clean_df.isna().sum().sum()
# Out:
# 0

# %%
df = clean_df

# %% [markdown]
# We split the columns to numerical and categorical ones for the analysis

# %%
bool_cols = ['is_repeated_guest', 'is_canceled']
numeric_cols = [col for col in df.columns if df[col].dtype in (int, float) and col not in bool_cols]
cat_cols = [col for col in df.columns if col not in numeric_cols and col not in bool_cols]

# %% [markdown]
# It seems that predicting the reservation status before it was closed can be a useful insight to the hotel managers.
# #### So we define a multi-class classification problem to predict the `reservation_status`

# %%
df.reservation_status.value_counts()
# Out:
# Check-Out    75166
# Canceled     43013
# No-Show       1207
# Name: reservation_status, dtype: int64

# %%
df['reservation_status'].value_counts() / df.shape[0]
# Out:
# Check-Out    0.629605
# Canceled     0.360285
# No-Show      0.010110
# Name: reservation_status, dtype: float64

# %% [markdown]
# Running an auto-analysis tool for preliminary statistical examination of the features

# %%
# import sweetviz as sv
#
# analyze_report = sv.analyze(df)
# analyze_report.show_html('analyze.html', open_browser=False)

# %% [markdown]
# ### First impression:
#
# our classification problem - predict the `reservation_status` of a given booking
# `is_canceled` is highly correlated with our label, and is probably unavailable during prediction time, so we omit that column as well (since business-wise it is unknown given a new instance for prediction)
# There seem to be some categorical/numerical/boolean columns that might have a significant signal for predicting `reservation_status`, so we would plot each ine of them and look for significant change groups reservation status
#
# The following columns are pairwise correlated:
# * stays_in_weekend_nights / stays_in_week_nights

# %%
df = df.drop(columns=['is_canceled']).dropna(axis=0)
bool_cols.remove('is_canceled')

# %% [markdown]
# #### Categorical data analysis

# %%
from matplotlib.pyplot import subplots_adjust

m = len(cat_cols)
plot_col_n = 3
_, ax = plt.subplots(3, plot_col_n, figsize=(35, 25))
subplots_adjust(hspace=0.4)
i = 0
for col in cat_cols:
    if col not in ['reservation_status', 'reservation_status_date', 'country']:
        _ax = ax[i // plot_col_n][i % plot_col_n]
        sns.countplot(data=df, x=col, hue="reservation_status", ax=_ax)
        _ax.set(title=f'{col} counts split by reservation_status\n({columns_mapping.get(col)})')
        i += 1
;
# Out:
# ''

# %% [markdown]
# We can see that `deposit_type`, `hotel`, `distribution_channel`, `market_segment`, and `assigned_room_type` contain some signal as to the label
# We encode the categorical features to identify correlations with the target label.

# %%
cat_cols = [col for col in cat_cols if col not in ['arrival_date_month', 'reservation_status_date']]
df_cat = df.copy()[cat_cols]
for col in cat_cols:
    df_cat[col] = df[col].astype('category').cat.codes

# %%
df_cat[cat_cols].head(5)
# Out:
#    hotel  meal  country  market_segment  distribution_channel  \
# 0      1     0      135               3                     1
# 1      1     0      135               3                     1
# 2      1     0       59               3                     1
# 3      1     0       59               2                     0
# 4      1     0       59               6                     3
#
#    reserved_room_type  assigned_room_type  deposit_type  customer_type  \
# 0                   2                   2             0              2
# 1                   2                   2             0              2
# 2                   0                   2             0              2
# 3                   0                   0             0              2
# 4                   0                   0             0              2
#
#    reservation_status
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
def plot_heatmaps(data: pd.DataFrame, figsize=(20, 10)):
    for name, method in [('pearson', pearsonr),
                         ('spearman', spearmanr)]:
        print('********************************************************************\n')
        print(f'{name}\n')
        _, ax = plt.subplots(1, figsize=figsize)
        sns.heatmap(data.corr(method=name).abs(), annot=True, ax=ax)
        ax.set(title=f'Abs {name} correlations values')
        print(f'correlations')
        print(data.corr(method=name))
        print(f'\np-value')
        print(data.corr(method=lambda x, y: method(x, y)[1]))

# %%
plot_heatmaps(df_cat)
# Out:
# ********************************************************************
#
# pearson
#
# correlations
#                          hotel      meal   country  market_segment  \
# hotel                 1.000000 -0.008031  0.050496       -0.083783
# meal                 -0.008031  1.000000 -0.089888        0.145150
# country               0.050496 -0.089888  1.000000       -0.273398
# market_segment       -0.083783  0.145150 -0.273398        1.000000
# distribution_channel -0.174390  0.116990 -0.135407        0.767776
# reserved_room_type    0.249680 -0.120749 -0.100142        0.094543
# assigned_room_type    0.307833 -0.120796 -0.074357        0.026382
# deposit_type         -0.159031 -0.092158  0.320834       -0.184846
# customer_type        -0.047498  0.044686  0.025932       -0.165859
# reservation_status    0.124305  0.015371 -0.240847       -0.061560
#
#                       distribution_channel  reserved_room_type  \
# hotel                            -0.174390            0.249680
# meal                              0.116990           -0.120749
# country                          -0.135407           -0.100142
# market_segment                    0.767776            0.094543
# distribution_channel              1.000000           -0.041722
# reserved_room_type               -0.041722            1.000000
# assigned_room_type               -0.104497            0.814005
# deposit_type                      0.092604           -0.199689
# customer_type                    -0.069724           -0.120983
# reservation_status               -0.171273            0.058695
#
#                       assigned_room_type  deposit_type  customer_type  \
# hotel                           0.307833     -0.159031      -0.047498
# meal                           -0.120796     -0.092158       0.044686
# country                        -0.074357      0.320834       0.025932
# market_segment                  0.026382     -0.184846      -0.165859
# distribution_channel           -0.104497      0.092604      -0.069724
# reserved_room_type              0.814005     -0.199689      -0.120983
# assigned_room_type              1.000000     -0.242387      -0.084421
# deposit_type                   -0.242387      1.000000      -0.076388
# customer_type                  -0.084421     -0.076388       1.000000
# reservation_status              0.172534     -0.466215       0.066074
#
#                       reservation_status
# hotel                           0.124305
# meal                            0.015371
# country                        -0.240847
# market_segment                 -0.061560
# distribution_channel           -0.171273
# reserved_room_type              0.058695
# assigned_room_type              0.172534
# deposit_type                   -0.466215
# customer_type                   0.066074
# reservation_status              1.000000
#
# p-value
#                               hotel           meal        country  \
# hotel                  1.000000e+00   5.524177e-03   2.976494e-68
# meal                   5.524177e-03   1.000000e+00  1.253471e-212
# country                2.976494e-68  1.253471e-212   1.000000e+00
# market_segment        6.647354e-185   0.000000e+00   0.000000e+00
# distribution_channel   0.000000e+00   0.000000e+00   0.000000e+00
# reserved_room_type     0.000000e+00   0.000000e+00  1.181653e-263
# assigned_room_type     0.000000e+00   0.000000e+00  5.787158e-146
# deposit_type           0.000000e+00  1.914472e-223   0.000000e+00
# customer_type          1.362627e-60   7.848577e-54   3.202272e-19
# reservation_status     0.000000e+00   1.088447e-07   0.000000e+00
#
#                       market_segment  distribution_channel  \
# hotel                  6.647354e-185          0.000000e+00
# meal                    0.000000e+00          0.000000e+00
# country                 0.000000e+00          0.000000e+00
# market_segment          1.000000e+00          0.000000e+00
# distribution_channel    0.000000e+00          1.000000e+00
# reserved_room_type     4.257513e-235          3.768319e-47
# assigned_room_type      7.720357e-20         5.097016e-287
# deposit_type            0.000000e+00         1.342189e-225
# customer_type           0.000000e+00         1.530438e-128
# reservation_status     1.394351e-100          0.000000e+00
#
#                       reserved_room_type  assigned_room_type   deposit_type  \
# hotel                       0.000000e+00        0.000000e+00   0.000000e+00
# meal                        0.000000e+00        0.000000e+00  1.914472e-223
# country                    1.181653e-263       5.787158e-146   0.000000e+00
# market_segment             4.257513e-235        7.720357e-20   0.000000e+00
# distribution_channel        3.768319e-47       5.097016e-287  1.342189e-225
# reserved_room_type          1.000000e+00        0.000000e+00   0.000000e+00
# assigned_room_type          0.000000e+00        1.000000e+00   0.000000e+00
# deposit_type                0.000000e+00        0.000000e+00   1.000000e+00
# customer_type               0.000000e+00       1.042167e-187  5.843889e-154
# reservation_status          1.348761e-91        0.000000e+00   0.000000e+00
#
#                       customer_type  reservation_status
# hotel                  1.362627e-60        0.000000e+00
# meal                   7.848577e-54        1.088447e-07
# country                3.202272e-19        0.000000e+00
# market_segment         0.000000e+00       1.394351e-100
# distribution_channel  1.530438e-128        0.000000e+00
# reserved_room_type     0.000000e+00        1.348761e-91
# assigned_room_type    1.042167e-187        0.000000e+00
# deposit_type          5.843889e-154        0.000000e+00
# customer_type          1.000000e+00       1.308543e-115
# reservation_status    1.308543e-115        1.000000e+00
# ********************************************************************
#
# spearman
#
# correlations
#                          hotel      meal   country  market_segment  \
# hotel                 1.000000  0.013582  0.066029       -0.075365
# meal                  0.013582  1.000000 -0.084520        0.120359
# country               0.066029 -0.084520  1.000000       -0.283495
# market_segment       -0.075365  0.120359 -0.283495        1.000000
# distribution_channel -0.178904  0.111181 -0.128169        0.667789
# reserved_room_type    0.235771 -0.115517 -0.102521        0.149241
# assigned_room_type    0.306029 -0.123323 -0.079630        0.076482
# deposit_type         -0.165649 -0.082877  0.313727       -0.275455
# customer_type        -0.041015  0.059405  0.022553       -0.252161
# reservation_status    0.127931  0.011963 -0.240437       -0.027139
#
#                       distribution_channel  reserved_room_type  \
# hotel                            -0.178904            0.235771
# meal                              0.111181           -0.115517
# country                          -0.128169           -0.102521
# market_segment                    0.667789            0.149241
# distribution_channel              1.000000           -0.054719
# reserved_room_type               -0.054719            1.000000
# assigned_room_type               -0.117819            0.813905
# deposit_type                      0.103444           -0.211434
# customer_type                    -0.039587           -0.158156
# reservation_status               -0.178930            0.066278
#
#                       assigned_room_type  deposit_type  customer_type  \
# hotel                           0.306029     -0.165649      -0.041015
# meal                           -0.123323     -0.082877       0.059405
# country                        -0.079630      0.313727       0.022553
# market_segment                  0.076482     -0.275455      -0.252161
# distribution_channel           -0.117819      0.103444      -0.039587
# reserved_room_type              0.813905     -0.211434      -0.158156
# assigned_room_type              1.000000     -0.261916      -0.110539
# deposit_type                   -0.261916      1.000000      -0.101687
# customer_type                  -0.110539     -0.101687       1.000000
# reservation_status              0.187980     -0.480675       0.096826
#
#                       reservation_status
# hotel                           0.127931
# meal                            0.011963
# country                        -0.240437
# market_segment                 -0.027139
# distribution_channel           -0.178930
# reserved_room_type              0.066278
# assigned_room_type              0.187980
# deposit_type                   -0.480675
# customer_type                   0.096826
# reservation_status              1.000000
#
# p-value
#                               hotel           meal        country  \
# hotel                  1.000000e+00   2.692077e-06  1.874756e-115
# meal                   2.692077e-06   1.000000e+00  3.813782e-188
# country               1.874756e-115  3.813782e-188   1.000000e+00
# market_segment        6.612755e-150   0.000000e+00   0.000000e+00
# distribution_channel   0.000000e+00   0.000000e+00   0.000000e+00
# reserved_room_type     0.000000e+00   0.000000e+00  2.730799e-276
# assigned_room_type     0.000000e+00   0.000000e+00  3.602526e-167
# deposit_type           0.000000e+00  5.853383e-181   0.000000e+00
# customer_type          1.266758e-45   8.762961e-94   6.513044e-15
# reservation_status     0.000000e+00   3.571056e-05   0.000000e+00
#
#                       market_segment  distribution_channel  \
# hotel                  6.612755e-150          0.000000e+00
# meal                    0.000000e+00          0.000000e+00
# country                 0.000000e+00          0.000000e+00
# market_segment          1.000000e+00          0.000000e+00
# distribution_channel    0.000000e+00          1.000000e+00
# reserved_room_type      0.000000e+00          7.696365e-80
# assigned_room_type     2.468891e-154          0.000000e+00
# deposit_type            0.000000e+00         2.815545e-281
# customer_type           0.000000e+00          1.278321e-42
# reservation_status      6.676970e-21          0.000000e+00
#
#                       reserved_room_type  assigned_room_type   deposit_type  \
# hotel                       0.000000e+00        0.000000e+00   0.000000e+00
# meal                        0.000000e+00        0.000000e+00  5.853383e-181
# country                    2.730799e-276       3.602526e-167   0.000000e+00
# market_segment              0.000000e+00       2.468891e-154   0.000000e+00
# distribution_channel        7.696365e-80        0.000000e+00  2.815545e-281
# reserved_room_type          1.000000e+00        0.000000e+00   0.000000e+00
# assigned_room_type          0.000000e+00        1.000000e+00   0.000000e+00
# deposit_type                0.000000e+00        0.000000e+00   1.000000e+00
# customer_type               0.000000e+00        0.000000e+00  7.933754e-272
# reservation_status         2.581168e-116        0.000000e+00   0.000000e+00
#
#                       customer_type  reservation_status
# hotel                  1.266758e-45        0.000000e+00
# meal                   8.762961e-94        3.571056e-05
# country                6.513044e-15        0.000000e+00
# market_segment         0.000000e+00        6.676970e-21
# distribution_channel   1.278321e-42        0.000000e+00
# reserved_room_type     0.000000e+00       2.581168e-116
# assigned_room_type     0.000000e+00        0.000000e+00
# deposit_type          7.933754e-272        0.000000e+00
# customer_type          1.000000e+00       1.538985e-246
# reservation_status    1.538985e-246        1.000000e+00

# %% [markdown]
# #### CAT data - Conclusion
# We can see with good confidence (very low p-val) that `deposit_type` has strong correlation to the reservation status, along with additional `assigned_room_type` `distribution_channel`, `country` and `hotel`

# %% [markdown]
# #### Numerical Data analysis

# %%
m = len(cat_cols)
plot_col_n = 3
_, ax = plt.subplots(6, plot_col_n, figsize=(30, 30))
subplots_adjust(hspace=0.4)
i = 0
for col in numeric_cols:
    _ax = ax[i // plot_col_n][i % plot_col_n]
    d = df[col].values
    sns.histplot(data=df, x=col, ax=_ax, hue='reservation_status', element="step", stat="density", common_norm=False,
                 bins=25)
    _ax.set(title=f'{col} distribution by reservation_status\n({columns_mapping.get(col)})')
    _ax.set_xlim(max(np.min(d), np.mean(d) - 3 * np.std(d)), np.mean(d) + 3 * np.std(d))
    i += 1
;
# Out:
# ''

# %%
df_num = df.copy()[numeric_cols + bool_cols]
df_num['reservation_status'] = df['reservation_status'].astype('category').cat.codes
plot_heatmaps(df_num)
# Out:
# ********************************************************************
#
# pearson
#
# correlations
#                                 lead_time  arrival_date_year  \
# lead_time                        1.000000           0.040093
# arrival_date_year                0.040093           1.000000
# arrival_date_week_number         0.126885          -0.540566
# arrival_date_day_of_month        0.002234          -0.000279
# stays_in_weekend_nights          0.085667           0.021489
# stays_in_week_nights             0.165799           0.030878
# adults                           0.119544           0.029674
# children                        -0.037622           0.054624
# babies                          -0.020918          -0.013197
# previous_cancellations           0.086040          -0.119833
# previous_bookings_not_canceled  -0.073552           0.029214
# booking_changes                  0.000138           0.030855
# agent                           -0.012661           0.056431
# days_in_waiting_list             0.170083          -0.056506
# adr                             -0.063126           0.197518
# required_car_parking_spaces     -0.116461          -0.013699
# total_of_special_requests       -0.095688           0.108585
# is_repeated_guest               -0.124418           0.010332
# reservation_status              -0.302229          -0.017756
#
#                                 arrival_date_week_number  \
# lead_time                                       0.126885
# arrival_date_year                              -0.540566
# arrival_date_week_number                        1.000000
# arrival_date_day_of_month                       0.066824
# stays_in_weekend_nights                         0.018209
# stays_in_week_nights                            0.015559
# adults                                          0.025901
# children                                        0.005518
# babies                                          0.010397
# previous_cancellations                          0.035502
# previous_bookings_not_canceled                 -0.020902
# booking_changes                                 0.005512
# agent                                          -0.018236
# days_in_waiting_list                            0.022935
# adr                                             0.075811
# required_car_parking_spaces                     0.001924
# total_of_special_requests                       0.026139
# is_repeated_guest                              -0.030129
# reservation_status                             -0.017371
#
#                                 arrival_date_day_of_month  \
# lead_time                                        0.002234
# arrival_date_year                               -0.000279
# arrival_date_week_number                         0.066824
# arrival_date_day_of_month                        1.000000
# stays_in_weekend_nights                         -0.016370
# stays_in_week_nights                            -0.028192
# adults                                          -0.001539
# children                                         0.014544
# babies                                          -0.000233
# previous_cancellations                          -0.027015
# previous_bookings_not_canceled                  -0.000303
# booking_changes                                  0.010601
# agent                                            0.000179
# days_in_waiting_list                             0.022723
# adr                                              0.030189
# required_car_parking_spaces                      0.008675
# total_of_special_requests                        0.003094
# is_repeated_guest                               -0.006152
# reservation_status                               0.011415
#
#                                 stays_in_weekend_nights  stays_in_week_nights  \
# lead_time                                      0.085667              0.165799
# arrival_date_year                              0.021489              0.030878
# arrival_date_week_number                       0.018209              0.015559
# arrival_date_day_of_month                     -0.016370             -0.028192
# stays_in_weekend_nights                        1.000000              0.498967
# stays_in_week_nights                           0.498967              1.000000
# adults                                         0.091889              0.092983
# children                                       0.045793              0.044203
# babies                                         0.018483              0.020191
# previous_cancellations                        -0.012775             -0.013993
# previous_bookings_not_canceled                -0.042716             -0.048744
# booking_changes                                0.063280              0.096210
# agent                                          0.161426              0.195136
# days_in_waiting_list                          -0.054153             -0.002020
# adr                                            0.049323              0.065219
# required_car_parking_spaces                   -0.018556             -0.024861
# total_of_special_requests                      0.072686              0.068199
# is_repeated_guest                             -0.087242             -0.097247
# reservation_status                             0.008551             -0.021614
#
#                                   adults  children    babies  \
# lead_time                       0.119544 -0.037622 -0.020918
# arrival_date_year               0.029674  0.054624 -0.013197
# arrival_date_week_number        0.025901  0.005518  0.010397
# arrival_date_day_of_month      -0.001539  0.014544 -0.000233
# stays_in_weekend_nights         0.091889  0.045793  0.018483
# stays_in_week_nights            0.092983  0.044203  0.020191
# adults                          1.000000  0.030447  0.018148
# children                        0.030447  1.000000  0.024030
# babies                          0.018148  0.024030  1.000000
# previous_cancellations         -0.006736 -0.024730 -0.007501
# previous_bookings_not_canceled -0.107983 -0.021072 -0.006551
# booking_changes                -0.051666  0.048949  0.083439
# agent                           0.025010  0.050576  0.030264
# days_in_waiting_list           -0.008280 -0.033273 -0.010621
# adr                             0.230690  0.324854  0.029183
# required_car_parking_spaces     0.014791  0.056253  0.037383
# total_of_special_requests       0.122855  0.081745  0.097893
# is_repeated_guest              -0.146425 -0.032859 -0.008943
# reservation_status             -0.071776 -0.003411  0.030968
#
#                                 previous_cancellations  \
# lead_time                                     0.086040
# arrival_date_year                            -0.119833
# arrival_date_week_number                      0.035502
# arrival_date_day_of_month                    -0.027015
# stays_in_weekend_nights                      -0.012775
# stays_in_week_nights                         -0.013993
# adults                                       -0.006736
# children                                     -0.024730
# babies                                       -0.007501
# previous_cancellations                        1.000000
# previous_bookings_not_canceled                0.152728
# booking_changes                              -0.026994
# agent                                        -0.018194
# days_in_waiting_list                          0.005928
# adr                                          -0.065653
# required_car_parking_spaces                  -0.018493
# total_of_special_requests                    -0.048382
# is_repeated_guest                             0.082293
# reservation_status                           -0.110765
#
#                                 previous_bookings_not_canceled  \
# lead_time                                            -0.073552
# arrival_date_year                                     0.029214
# arrival_date_week_number                             -0.020902
# arrival_date_day_of_month                            -0.000303
# stays_in_weekend_nights                              -0.042716
# stays_in_week_nights                                 -0.048744
# adults                                               -0.107983
# children                                             -0.021072
# babies                                               -0.006551
# previous_cancellations                                0.152728
# previous_bookings_not_canceled                        1.000000
# booking_changes                                       0.011607
# agent                                                -0.046299
# days_in_waiting_list                                 -0.009397
# adr                                                  -0.072151
# required_car_parking_spaces                           0.047652
# total_of_special_requests                             0.037827
# is_repeated_guest                                     0.418056
# reservation_status                                    0.055048
#
#                                 booking_changes     agent  \
# lead_time                              0.000138 -0.012661
# arrival_date_year                      0.030855  0.056431
# arrival_date_week_number               0.005512 -0.018236
# arrival_date_day_of_month              0.010601  0.000179
# stays_in_weekend_nights                0.063280  0.161426
# stays_in_week_nights                   0.096210  0.195136
# adults                                -0.051666  0.025010
# children                               0.048949  0.050576
# babies                                 0.083439  0.030264
# previous_cancellations                -0.026994 -0.018194
# previous_bookings_not_canceled         0.011607 -0.046299
# booking_changes                        1.000000  0.036471
# agent                                  0.036471  1.000000
# days_in_waiting_list                  -0.011635 -0.040856
# adr                                    0.019602  0.016677
# required_car_parking_spaces            0.065617  0.119153
# total_of_special_requests              0.052844  0.060717
# is_repeated_guest                      0.012090 -0.052268
# reservation_status                     0.140789  0.040010
#
#                                 days_in_waiting_list       adr  \
# lead_time                                   0.170083 -0.063126
# arrival_date_year                          -0.056506  0.197518
# arrival_date_week_number                    0.022935  0.075811
# arrival_date_day_of_month                   0.022723  0.030189
# stays_in_weekend_nights                    -0.054153  0.049323
# stays_in_week_nights                       -0.002020  0.065219
# adults                                     -0.008280  0.230690
# children                                   -0.033273  0.324854
# babies                                     -0.010621  0.029183
# previous_cancellations                      0.005928 -0.065653
# previous_bookings_not_canceled             -0.009397 -0.072151
# booking_changes                            -0.011635  0.019602
# agent                                      -0.040856  0.016677
# days_in_waiting_list                        1.000000 -0.040764
# adr                                        -0.040764  1.000000
# required_car_parking_spaces                -0.030601  0.056618
# total_of_special_requests                  -0.082727  0.172238
# is_repeated_guest                          -0.022236 -0.134328
# reservation_status                         -0.057935 -0.050586
#
#                                 required_car_parking_spaces  \
# lead_time                                         -0.116461
# arrival_date_year                                 -0.013699
# arrival_date_week_number                           0.001924
# arrival_date_day_of_month                          0.008675
# stays_in_weekend_nights                           -0.018556
# stays_in_week_nights                              -0.024861
# adults                                             0.014791
# children                                           0.056253
# babies                                             0.037383
# previous_cancellations                            -0.018493
# previous_bookings_not_canceled                     0.047652
# booking_changes                                    0.065617
# agent                                              0.119153
# days_in_waiting_list                              -0.030601
# adr                                                0.056618
# required_car_parking_spaces                        1.000000
# total_of_special_requests                          0.082635
# is_repeated_guest                                  0.077088
# reservation_status                                 0.179304
#
#                                 total_of_special_requests  is_repeated_guest  \
# lead_time                                       -0.095688          -0.124418
# arrival_date_year                                0.108585           0.010332
# arrival_date_week_number                         0.026139          -0.030129
# arrival_date_day_of_month                        0.003094          -0.006152
# stays_in_weekend_nights                          0.072686          -0.087242
# stays_in_week_nights                             0.068199          -0.097247
# adults                                           0.122855          -0.146425
# children                                         0.081745          -0.032859
# babies                                           0.097893          -0.008943
# previous_cancellations                          -0.048382           0.082293
# previous_bookings_not_canceled                   0.037827           0.418056
# booking_changes                                  0.052844           0.012090
# agent                                            0.060717          -0.052268
# days_in_waiting_list                            -0.082727          -0.022236
# adr                                              0.172238          -0.134328
# required_car_parking_spaces                      0.082635           0.077088
# total_of_special_requests                        1.000000           0.013055
# is_repeated_guest                                0.013055           1.000000
# reservation_status                               0.225722           0.083498
#
#                                 reservation_status
# lead_time                                -0.302229
# arrival_date_year                        -0.017756
# arrival_date_week_number                 -0.017371
# arrival_date_day_of_month                 0.011415
# stays_in_weekend_nights                   0.008551
# stays_in_week_nights                     -0.021614
# adults                                   -0.071776
# children                                 -0.003411
# babies                                    0.030968
# previous_cancellations                   -0.110765
# previous_bookings_not_canceled            0.055048
# booking_changes                           0.140789
# agent                                     0.040010
# days_in_waiting_list                     -0.057935
# adr                                      -0.050586
# required_car_parking_spaces               0.179304
# total_of_special_requests                 0.225722
# is_repeated_guest                         0.083498
# reservation_status                        1.000000
#
# p-value
#                                     lead_time  arrival_date_year  \
# lead_time                        1.000000e+00       1.132068e-43
# arrival_date_year                1.132068e-43       1.000000e+00
# arrival_date_week_number         0.000000e+00       0.000000e+00
# arrival_date_day_of_month        4.402356e-01       9.231926e-01
# stays_in_weekend_nights         2.998099e-193       1.122141e-13
# stays_in_week_nights             0.000000e+00       1.384180e-26
# adults                           0.000000e+00       1.120714e-24
# children                         1.166952e-38       1.437177e-79
# babies                           4.889631e-13       5.113856e-06
# previous_cancellations          6.360963e-195       0.000000e+00
# previous_bookings_not_canceled  7.398259e-143       5.738204e-24
# booking_changes                  9.619434e-01       1.506345e-26
# agent                            1.216315e-05       8.420501e-85
# days_in_waiting_list             0.000000e+00       5.052977e-85
# adr                             1.127273e-105       0.000000e+00
# required_car_parking_spaces      0.000000e+00       2.206930e-06
# total_of_special_requests       8.422232e-241      7.070373e-310
# is_repeated_guest                0.000000e+00       3.570571e-04
# reservation_status               0.000000e+00       8.492771e-10
#
#                                 arrival_date_week_number  \
# lead_time                                   0.000000e+00
# arrival_date_year                           0.000000e+00
# arrival_date_week_number                    1.000000e+00
# arrival_date_day_of_month                  3.294292e-118
# stays_in_weekend_nights                     3.129800e-10
# stays_in_week_nights                        7.600274e-08
# adults                                      3.525841e-19
# children                                    5.655503e-02
# babies                                      3.277765e-04
# previous_cancellations                      1.303000e-34
# previous_bookings_not_canceled              5.085717e-13
# booking_changes                             5.685325e-02
# agent                                       2.947676e-10
# days_in_waiting_list                        2.273498e-15
# adr                                        1.148770e-151
# required_car_parking_spaces                 5.062753e-01
# total_of_special_requests                   1.667380e-19
# is_repeated_guest                           2.177485e-25
# reservation_status                          1.942361e-09
#
#                                 arrival_date_day_of_month  \
# lead_time                                    4.402356e-01
# arrival_date_year                            9.231926e-01
# arrival_date_week_number                    3.294292e-118
# arrival_date_day_of_month                    1.000000e+00
# stays_in_weekend_nights                      1.543908e-08
# stays_in_week_nights                         1.976846e-22
# adults                                       5.947857e-01
# children                                     5.022813e-07
# babies                                       9.357623e-01
# previous_cancellations                       1.001212e-20
# previous_bookings_not_canceled               9.166085e-01
# booking_changes                              2.492978e-04
# agent                                        9.508041e-01
# days_in_waiting_list                         4.082457e-15
# adr                                          1.750481e-25
# required_car_parking_spaces                  2.723778e-03
# total_of_special_requests                    2.849866e-01
# is_repeated_guest                            3.354356e-02
# reservation_status                           8.009204e-05
#
#                                 stays_in_weekend_nights  stays_in_week_nights  \
# lead_time                                 2.998099e-193          0.000000e+00
# arrival_date_year                          1.122141e-13          1.384180e-26
# arrival_date_week_number                   3.129800e-10          7.600274e-08
# arrival_date_day_of_month                  1.543908e-08          1.976846e-22
# stays_in_weekend_nights                    1.000000e+00          0.000000e+00
# stays_in_week_nights                       0.000000e+00          1.000000e+00
# adults                                    3.815183e-222         1.924848e-227
# children                                   1.912591e-56          1.032660e-52
# babies                                     1.695915e-10          3.014185e-12
# previous_cancellations                     1.013268e-05          1.330655e-06
# previous_bookings_not_canceled             2.425481e-49          1.016053e-63
# booking_changes                           3.496928e-106         2.010827e-243
# agent                                      0.000000e+00          0.000000e+00
# days_in_waiting_list                       3.126498e-78          4.851179e-01
# adr                                        3.347986e-65         1.105968e-112
# required_car_parking_spaces                1.437567e-10          8.602092e-18
# total_of_special_requests                 1.498494e-139         4.703466e-123
# is_repeated_guest                         2.282334e-200         1.110074e-248
# reservation_status                         3.131728e-03          8.092220e-14
#
#                                        adults       children         babies  \
# lead_time                        0.000000e+00   1.166952e-38   4.889631e-13
# arrival_date_year                1.120714e-24   1.437177e-79   5.113856e-06
# arrival_date_week_number         3.525841e-19   5.655503e-02   3.277765e-04
# arrival_date_day_of_month        5.947857e-01   5.022813e-07   9.357623e-01
# stays_in_weekend_nights         3.815183e-222   1.912591e-56   1.695915e-10
# stays_in_week_nights            1.924848e-227   1.032660e-52   3.014185e-12
# adults                           1.000000e+00   6.810929e-26   3.588906e-10
# children                         6.810929e-26   1.000000e+00   1.007739e-16
# babies                           3.588906e-10   1.007739e-16   1.000000e+00
# previous_cancellations           1.994418e-02   1.273945e-17   9.545488e-03
# previous_bookings_not_canceled  1.873540e-306   3.294979e-13   2.360988e-02
# booking_changes                  2.267986e-71   3.049125e-64  2.119848e-183
# agent                            5.492277e-18   1.828798e-68   1.329515e-25
# days_in_waiting_list             4.221520e-03   1.326656e-30   2.427112e-04
# adr                              0.000000e+00   0.000000e+00   6.409777e-24
# required_car_parking_spaces      3.207717e-07   2.811605e-84   3.428501e-38
# total_of_special_requests        0.000000e+00  4.364746e-176  5.563660e-252
# is_repeated_guest                0.000000e+00   6.875897e-30   2.000980e-03
# reservation_status              4.060122e-136   2.386328e-01   9.894516e-27
#
#                                 previous_cancellations  \
# lead_time                                6.360963e-195
# arrival_date_year                         0.000000e+00
# arrival_date_week_number                  1.303000e-34
# arrival_date_day_of_month                 1.001212e-20
# stays_in_weekend_nights                   1.013268e-05
# stays_in_week_nights                      1.330655e-06
# adults                                    1.994418e-02
# children                                  1.273945e-17
# babies                                    9.545488e-03
# previous_cancellations                    1.000000e+00
# previous_bookings_not_canceled            0.000000e+00
# booking_changes                           1.072717e-20
# agent                                     3.236381e-10
# days_in_waiting_list                      4.051846e-02
# adr                                      3.656801e-114
# required_car_parking_spaces               1.655757e-10
# total_of_special_requests                 8.374467e-63
# is_repeated_guest                        1.956959e-178
# reservation_status                       1.976263e-322
#
#                                 previous_bookings_not_canceled  \
# lead_time                                        7.398259e-143
# arrival_date_year                                 5.738204e-24
# arrival_date_week_number                          5.085717e-13
# arrival_date_day_of_month                         9.166085e-01
# stays_in_weekend_nights                           2.425481e-49
# stays_in_week_nights                              1.016053e-63
# adults                                           1.873540e-306
# children                                          3.294979e-13
# babies                                            2.360988e-02
# previous_cancellations                            0.000000e+00
# previous_bookings_not_canceled                    1.000000e+00
# booking_changes                                   6.061395e-05
# agent                                             1.167329e-57
# days_in_waiting_list                              1.166083e-03
# adr                                              1.572893e-137
# required_car_parking_spaces                       5.626116e-61
# total_of_special_requests                         4.596526e-39
# is_repeated_guest                                 0.000000e+00
# reservation_status                                8.804211e-81
#
#                                 booking_changes         agent  \
# lead_time                          9.619434e-01  1.216315e-05
# arrival_date_year                  1.506345e-26  8.420501e-85
# arrival_date_week_number           5.685325e-02  2.947676e-10
# arrival_date_day_of_month          2.492978e-04  9.508041e-01
# stays_in_weekend_nights           3.496928e-106  0.000000e+00
# stays_in_week_nights              2.010827e-243  0.000000e+00
# adults                             2.267986e-71  5.492277e-18
# children                           3.049125e-64  1.828798e-68
# babies                            2.119848e-183  1.329515e-25
# previous_cancellations             1.072717e-20  3.236381e-10
# previous_bookings_not_canceled     6.061395e-05  1.167329e-57
# booking_changes                    1.000000e+00  1.962500e-36
# agent                              1.962500e-36  1.000000e+00
# days_in_waiting_list               5.809604e-05  2.758517e-45
# adr                                1.256136e-11  8.287030e-09
# required_car_parking_spaces       4.844054e-114  0.000000e+00
# total_of_special_requests          1.397121e-74  6.807716e-98
# is_repeated_guest                  2.948669e-05  5.293672e-73
# reservation_status                 0.000000e+00  1.682547e-43
#
#                                 days_in_waiting_list            adr  \
# lead_time                               0.000000e+00  1.127273e-105
# arrival_date_year                       5.052977e-85   0.000000e+00
# arrival_date_week_number                2.273498e-15  1.148770e-151
# arrival_date_day_of_month               4.082457e-15   1.750481e-25
# stays_in_weekend_nights                 3.126498e-78   3.347986e-65
# stays_in_week_nights                    4.851179e-01  1.105968e-112
# adults                                  4.221520e-03   0.000000e+00
# children                                1.326656e-30   0.000000e+00
# babies                                  2.427112e-04   6.409777e-24
# previous_cancellations                  4.051846e-02  3.656801e-114
# previous_bookings_not_canceled          1.166083e-03  1.572893e-137
# booking_changes                         5.809604e-05   1.256136e-11
# agent                                   2.758517e-45   8.287030e-09
# days_in_waiting_list                    1.000000e+00   4.331562e-45
# adr                                     4.331562e-45   1.000000e+00
# required_car_parking_spaces             3.859400e-26   2.364865e-85
# total_of_special_requests              2.611128e-180   0.000000e+00
# is_repeated_guest                       1.543888e-14   0.000000e+00
# reservation_status                      2.763497e-89   1.720397e-68
#
#                                 required_car_parking_spaces  \
# lead_time                                      0.000000e+00
# arrival_date_year                              2.206930e-06
# arrival_date_week_number                       5.062753e-01
# arrival_date_day_of_month                      2.723778e-03
# stays_in_weekend_nights                        1.437567e-10
# stays_in_week_nights                           8.602092e-18
# adults                                         3.207717e-07
# children                                       2.811605e-84
# babies                                         3.428501e-38
# previous_cancellations                         1.655757e-10
# previous_bookings_not_canceled                 5.626116e-61
# booking_changes                               4.844054e-114
# agent                                          0.000000e+00
# days_in_waiting_list                           3.859400e-26
# adr                                            2.364865e-85
# required_car_parking_spaces                    1.000000e+00
# total_of_special_requests                     6.536985e-180
# is_repeated_guest                             9.148528e-157
# reservation_status                             0.000000e+00
#
#                                 total_of_special_requests  is_repeated_guest  \
# lead_time                                   8.422232e-241       0.000000e+00
# arrival_date_year                           7.070373e-310       3.570571e-04
# arrival_date_week_number                     1.667380e-19       2.177485e-25
# arrival_date_day_of_month                    2.849866e-01       3.354356e-02
# stays_in_weekend_nights                     1.498494e-139      2.282334e-200
# stays_in_week_nights                        4.703466e-123      1.110074e-248
# adults                                       0.000000e+00       0.000000e+00
# children                                    4.364746e-176       6.875897e-30
# babies                                      5.563660e-252       2.000980e-03
# previous_cancellations                       8.374467e-63      1.956959e-178
# previous_bookings_not_canceled               4.596526e-39       0.000000e+00
# booking_changes                              1.397121e-74       2.948669e-05
# agent                                        6.807716e-98       5.293672e-73
# days_in_waiting_list                        2.611128e-180       1.543888e-14
# adr                                          0.000000e+00       0.000000e+00
# required_car_parking_spaces                 6.536985e-180      9.148528e-157
# total_of_special_requests                    1.000000e+00       6.449230e-06
# is_repeated_guest                            6.449230e-06       1.000000e+00
# reservation_status                           0.000000e+00      1.170788e-183
#
#                                 reservation_status
# lead_time                             0.000000e+00
# arrival_date_year                     8.492771e-10
# arrival_date_week_number              1.942361e-09
# arrival_date_day_of_month             8.009204e-05
# stays_in_weekend_nights               3.131728e-03
# stays_in_week_nights                  8.092220e-14
# adults                               4.060122e-136
# children                              2.386328e-01
# babies                                9.894516e-27
# previous_cancellations               1.976263e-322
# previous_bookings_not_canceled        8.804211e-81
# booking_changes                       0.000000e+00
# agent                                 1.682547e-43
# days_in_waiting_list                  2.763497e-89
# adr                                   1.720397e-68
# required_car_parking_spaces           0.000000e+00
# total_of_special_requests             0.000000e+00
# is_repeated_guest                    1.170788e-183
# reservation_status                    1.000000e+00
# ********************************************************************
#
# spearman
#
# correlations
#                                 lead_time  arrival_date_year  \
# lead_time                        1.000000           0.056582
# arrival_date_year                0.056582           1.000000
# arrival_date_week_number         0.112537          -0.544814
# arrival_date_day_of_month        0.007488          -0.001236
# stays_in_weekend_nights          0.162108           0.024798
# stays_in_week_nights             0.296348           0.041297
# adults                           0.192291           0.042911
# children                        -0.016159           0.057876
# babies                          -0.019787          -0.013276
# previous_cancellations           0.170798          -0.257695
# previous_bookings_not_canceled  -0.188621           0.036265
# booking_changes                 -0.007791           0.022544
# agent                            0.068160           0.078780
# days_in_waiting_list             0.153210          -0.083072
# adr                              0.014963           0.219500
# required_car_parking_spaces     -0.141561          -0.016315
# total_of_special_requests       -0.074062           0.115663
# is_repeated_guest               -0.190201           0.010368
# reservation_status              -0.328535          -0.019545
#
#                                 arrival_date_week_number  \
# lead_time                                       0.112537
# arrival_date_year                              -0.544814
# arrival_date_week_number                        1.000000
# arrival_date_day_of_month                       0.060766
# stays_in_weekend_nights                         0.025605
# stays_in_week_nights                            0.025905
# adults                                          0.026314
# children                                        0.006415
# babies                                          0.012544
# previous_cancellations                          0.086920
# previous_bookings_not_canceled                 -0.043138
# booking_changes                                 0.007866
# agent                                          -0.022036
# days_in_waiting_list                           -0.003533
# adr                                             0.073652
# required_car_parking_spaces                     0.003142
# total_of_special_requests                       0.019040
# is_repeated_guest                              -0.030377
# reservation_status                             -0.015583
#
#                                 arrival_date_day_of_month  \
# lead_time                                        0.007488
# arrival_date_year                               -0.001236
# arrival_date_week_number                         0.060766
# arrival_date_day_of_month                        1.000000
# stays_in_weekend_nights                         -0.006737
# stays_in_week_nights                            -0.015528
# adults                                           0.001555
# children                                         0.015654
# babies                                           0.000456
# previous_cancellations                          -0.011945
# previous_bookings_not_canceled                  -0.001384
# booking_changes                                  0.012444
# agent                                            0.001151
# days_in_waiting_list                             0.032200
# adr                                              0.026694
# required_car_parking_spaces                      0.008496
# total_of_special_requests                        0.003127
# is_repeated_guest                               -0.006090
# reservation_status                               0.010636
#
#                                 stays_in_weekend_nights  stays_in_week_nights  \
# lead_time                                      0.162108              0.296348
# arrival_date_year                              0.024798              0.041297
# arrival_date_week_number                       0.025605              0.025905
# arrival_date_day_of_month                     -0.006737             -0.015528
# stays_in_weekend_nights                        1.000000              0.238048
# stays_in_week_nights                           0.238048              1.000000
# adults                                         0.126778              0.152966
# children                                       0.052843              0.054301
# babies                                         0.022699              0.026459
# previous_cancellations                        -0.054982             -0.062176
# previous_bookings_not_canceled                -0.083601             -0.119104
# booking_changes                                0.040367              0.064484
# agent                                          0.179921              0.213725
# days_in_waiting_list                          -0.074751              0.011744
# adr                                            0.051348              0.093780
# required_car_parking_spaces                   -0.018620             -0.033856
# total_of_special_requests                      0.079394              0.076234
# is_repeated_guest                             -0.097074             -0.128400
# reservation_status                             0.007466             -0.045588
#
#                                   adults  children    babies  \
# lead_time                       0.192291 -0.016159 -0.019787
# arrival_date_year               0.042911  0.057876 -0.013276
# arrival_date_week_number        0.026314  0.006415  0.012544
# arrival_date_day_of_month       0.001555  0.015654  0.000456
# stays_in_weekend_nights         0.126778  0.052843  0.022699
# stays_in_week_nights            0.152966  0.054301  0.026459
# adults                          1.000000  0.072101  0.027670
# children                        0.072101  1.000000  0.039268
# babies                          0.027670  0.039268  1.000000
# previous_cancellations         -0.035986 -0.058644 -0.017287
# previous_bookings_not_canceled -0.209618 -0.035196 -0.011111
# booking_changes                -0.084983  0.065886  0.116057
# agent                           0.106283  0.057647  0.026850
# days_in_waiting_list           -0.036530 -0.048082 -0.014114
# adr                             0.279825  0.265465  0.026089
# required_car_parking_spaces     0.017918  0.060977  0.040576
# total_of_special_requests       0.161530  0.095661  0.092833
# is_repeated_guest              -0.176971 -0.034728 -0.009425
# reservation_status             -0.080008  0.003439  0.033448
#
#                                 previous_cancellations  \
# lead_time                                     0.170798
# arrival_date_year                            -0.257695
# arrival_date_week_number                      0.086920
# arrival_date_day_of_month                    -0.011945
# stays_in_weekend_nights                      -0.054982
# stays_in_week_nights                         -0.062176
# adults                                       -0.035986
# children                                     -0.058644
# babies                                       -0.017287
# previous_cancellations                        1.000000
# previous_bookings_not_canceled                0.101674
# booking_changes                              -0.072665
# agent                                        -0.126758
# days_in_waiting_list                          0.116299
# adr                                          -0.149860
# required_car_parking_spaces                  -0.043879
# total_of_special_requests                    -0.129441
# is_repeated_guest                             0.153317
# reservation_status                           -0.274275
#
#                                 previous_bookings_not_canceled  \
# lead_time                                            -0.188621
# arrival_date_year                                     0.036265
# arrival_date_week_number                             -0.043138
# arrival_date_day_of_month                            -0.001384
# stays_in_weekend_nights                              -0.083601
# stays_in_week_nights                                 -0.119104
# adults                                               -0.209618
# children                                             -0.035196
# babies                                               -0.011111
# previous_cancellations                                0.101674
# previous_bookings_not_canceled                        1.000000
# booking_changes                                       0.030675
# agent                                                -0.155100
# days_in_waiting_list                                 -0.018866
# adr                                                  -0.142795
# required_car_parking_spaces                           0.103914
# total_of_special_requests                             0.025022
# is_repeated_guest                                     0.757075
# reservation_status                                    0.113737
#
#                                 booking_changes     agent  \
# lead_time                             -0.007791  0.068160
# arrival_date_year                      0.022544  0.078780
# arrival_date_week_number               0.007866 -0.022036
# arrival_date_day_of_month              0.012444  0.001151
# stays_in_weekend_nights                0.040367  0.179921
# stays_in_week_nights                   0.064484  0.213725
# adults                                -0.084983  0.106283
# children                               0.065886  0.057647
# babies                                 0.116057  0.026850
# previous_cancellations                -0.072665 -0.126758
# previous_bookings_not_canceled         0.030675 -0.155100
# booking_changes                        1.000000  0.010219
# agent                                  0.010219  1.000000
# days_in_waiting_list                  -0.018959  0.014948
# adr                                    0.005210  0.058950
# required_car_parking_spaces            0.075657  0.056017
# total_of_special_requests              0.041925  0.087452
# is_repeated_guest                      0.018333 -0.139977
# reservation_status                     0.182466  0.023625
#
#                                 days_in_waiting_list       adr  \
# lead_time                                   0.153210  0.014963
# arrival_date_year                          -0.083072  0.219500
# arrival_date_week_number                   -0.003533  0.073652
# arrival_date_day_of_month                   0.032200  0.026694
# stays_in_weekend_nights                    -0.074751  0.051348
# stays_in_week_nights                        0.011744  0.093780
# adults                                     -0.036530  0.279825
# children                                   -0.048082  0.265465
# babies                                     -0.014114  0.026089
# previous_cancellations                      0.116299 -0.149860
# previous_bookings_not_canceled             -0.018866 -0.142795
# booking_changes                            -0.018959  0.005210
# agent                                       0.014948  0.058950
# days_in_waiting_list                        1.000000 -0.039533
# adr                                        -0.039533  1.000000
# required_car_parking_spaces                -0.043406  0.032696
# total_of_special_requests                  -0.123279  0.196470
# is_repeated_guest                          -0.027590 -0.151402
# reservation_status                         -0.103055 -0.054156
#
#                                 required_car_parking_spaces  \
# lead_time                                         -0.141561
# arrival_date_year                                 -0.016315
# arrival_date_week_number                           0.003142
# arrival_date_day_of_month                          0.008496
# stays_in_weekend_nights                           -0.018620
# stays_in_week_nights                              -0.033856
# adults                                             0.017918
# children                                           0.060977
# babies                                             0.040576
# previous_cancellations                            -0.043879
# previous_bookings_not_canceled                     0.103914
# booking_changes                                    0.075657
# agent                                              0.056017
# days_in_waiting_list                              -0.043406
# adr                                                0.032696
# required_car_parking_spaces                        1.000000
# total_of_special_requests                          0.087607
# is_repeated_guest                                  0.075315
# reservation_status                                 0.186078
#
#                                 total_of_special_requests  is_repeated_guest  \
# lead_time                                       -0.074062          -0.190201
# arrival_date_year                                0.115663           0.010368
# arrival_date_week_number                         0.019040          -0.030377
# arrival_date_day_of_month                        0.003127          -0.006090
# stays_in_weekend_nights                          0.079394          -0.097074
# stays_in_week_nights                             0.076234          -0.128400
# adults                                           0.161530          -0.176971
# children                                         0.095661          -0.034728
# babies                                           0.092833          -0.009425
# previous_cancellations                          -0.129441           0.153317
# previous_bookings_not_canceled                   0.025022           0.757075
# booking_changes                                  0.041925           0.018333
# agent                                            0.087452          -0.139977
# days_in_waiting_list                            -0.123279          -0.027590
# adr                                              0.196470          -0.151402
# required_car_parking_spaces                      0.087607           0.075315
# total_of_special_requests                        1.000000           0.005533
# is_repeated_guest                                0.005533           1.000000
# reservation_status                               0.253662           0.084728
#
#                                 reservation_status
# lead_time                                -0.328535
# arrival_date_year                        -0.019545
# arrival_date_week_number                 -0.015583
# arrival_date_day_of_month                 0.010636
# stays_in_weekend_nights                   0.007466
# stays_in_week_nights                     -0.045588
# adults                                   -0.080008
# children                                  0.003439
# babies                                    0.033448
# previous_cancellations                   -0.274275
# previous_bookings_not_canceled            0.113737
# booking_changes                           0.182466
# agent                                     0.023625
# days_in_waiting_list                     -0.103055
# adr                                      -0.054156
# required_car_parking_spaces               0.186078
# total_of_special_requests                 0.253662
# is_repeated_guest                         0.084728
# reservation_status                        1.000000
#
# p-value
#                                     lead_time  arrival_date_year  \
# lead_time                        1.000000e+00       3.030323e-85
# arrival_date_year                3.030323e-85       1.000000e+00
# arrival_date_week_number         0.000000e+00       0.000000e+00
# arrival_date_day_of_month        9.674112e-03       6.692792e-01
# stays_in_weekend_nights          0.000000e+00       1.039357e-17
# stays_in_week_nights             0.000000e+00       3.137217e-46
# adults                           0.000000e+00       8.902928e-50
# children                         2.357430e-08       4.141583e-89
# babies                           8.060046e-12       4.490389e-06
# previous_cancellations           0.000000e+00       0.000000e+00
# previous_bookings_not_canceled   0.000000e+00       4.831966e-36
# booking_changes                  7.099965e-03       6.678876e-15
# agent                           6.490320e-123      1.182107e-163
# days_in_waiting_list             0.000000e+00      8.350292e-182
# adr                              2.337740e-07       0.000000e+00
# required_car_parking_spaces      0.000000e+00       1.724767e-08
# total_of_special_requests       8.008485e-145       0.000000e+00
# is_repeated_guest                0.000000e+00       3.405556e-04
# reservation_status               0.000000e+00       1.440063e-11
#
#                                 arrival_date_week_number  \
# lead_time                                   0.000000e+00
# arrival_date_year                           0.000000e+00
# arrival_date_week_number                    1.000000e+00
# arrival_date_day_of_month                   4.758131e-98
# stays_in_weekend_nights                     8.877806e-19
# stays_in_week_nights                        3.485862e-19
# adults                                      9.593756e-20
# children                                    2.664824e-02
# babies                                      1.462404e-05
# previous_cancellations                     6.653096e-199
# previous_bookings_not_canceled              2.753100e-50
# booking_changes                             6.568161e-03
# agent                                       2.641127e-14
# days_in_waiting_list                        2.222217e-01
# adr                                        3.057874e-143
# required_car_parking_spaces                 2.775941e-01
# total_of_special_requests                   4.722379e-11
# is_repeated_guest                           8.792672e-26
# reservation_status                          7.261757e-08
#
#                                 arrival_date_day_of_month  \
# lead_time                                    9.674112e-03
# arrival_date_year                            6.692792e-01
# arrival_date_week_number                     4.758131e-98
# arrival_date_day_of_month                    1.000000e+00
# stays_in_weekend_nights                      1.991998e-02
# stays_in_week_nights                         8.070740e-08
# adults                                       5.911160e-01
# children                                     6.339166e-08
# babies                                       8.746709e-01
# previous_cancellations                       3.667548e-05
# previous_bookings_not_canceled               6.325156e-01
# booking_changes                              1.708931e-05
# agent                                        6.908329e-01
# days_in_waiting_list                         9.113989e-29
# adr                                          2.834528e-20
# required_car_parking_spaces                  3.327712e-03
# total_of_special_requests                    2.798717e-01
# is_repeated_guest                            3.535918e-02
# reservation_status                           2.377855e-04
#
#                                 stays_in_weekend_nights  stays_in_week_nights  \
# lead_time                                  0.000000e+00          0.000000e+00
# arrival_date_year                          1.039357e-17          3.137217e-46
# arrival_date_week_number                   8.877806e-19          3.485862e-19
# arrival_date_day_of_month                  1.991998e-02          8.070740e-08
# stays_in_weekend_nights                    1.000000e+00          0.000000e+00
# stays_in_week_nights                       0.000000e+00          1.000000e+00
# adults                                     0.000000e+00          0.000000e+00
# children                                   1.409975e-74          1.186075e-78
# babies                                     4.360052e-15          6.028374e-20
# previous_cancellations                     1.361756e-80         1.429186e-102
# previous_bookings_not_canceled            4.161439e-184          0.000000e+00
# booking_changes                            3.009400e-44         3.409472e-110
# agent                                      0.000000e+00          0.000000e+00
# days_in_waiting_list                      1.696406e-147          4.948018e-05
# adr                                        1.624777e-70         2.448374e-231
# required_car_parking_spaces                1.242844e-10          1.253646e-31
# total_of_special_requests                 3.446921e-166         2.412779e-153
# is_repeated_guest                         8.441417e-248          0.000000e+00
# reservation_status                         9.891900e-03          5.898075e-56
#
#                                        adults       children         babies  \
# lead_time                        0.000000e+00   2.357430e-08   8.060046e-12
# arrival_date_year                8.902928e-50   4.141583e-89   4.490389e-06
# arrival_date_week_number         9.593756e-20   2.664824e-02   1.462404e-05
# arrival_date_day_of_month        5.911160e-01   6.339166e-08   8.746709e-01
# stays_in_weekend_nights          0.000000e+00   1.409975e-74   4.360052e-15
# stays_in_week_nights             0.000000e+00   1.186075e-78   6.028374e-20
# adults                           1.000000e+00  2.428598e-137   1.151461e-21
# children                        2.428598e-137   1.000000e+00   5.797115e-42
# babies                           1.151461e-21   5.797115e-42   1.000000e+00
# previous_cancellations           1.624957e-35   1.926419e-91   2.325218e-09
# previous_bookings_not_canceled   0.000000e+00   4.785981e-34   1.234096e-04
# booking_changes                 3.389177e-190  5.813284e-115   0.000000e+00
# agent                           6.744590e-297   2.039453e-88   1.712523e-20
# days_in_waiting_list             1.515280e-36   4.747059e-62   1.077633e-06
# adr                              0.000000e+00   0.000000e+00   1.952972e-19
# required_car_parking_spaces      5.957102e-10   1.014928e-98   1.089780e-44
# total_of_special_requests        0.000000e+00  1.151627e-240  1.036371e-226
# is_repeated_guest                0.000000e+00   3.427546e-33   1.128033e-03
# reservation_status              9.581359e-169   2.347799e-01   6.549740e-31
#
#                                 previous_cancellations  \
# lead_time                                 0.000000e+00
# arrival_date_year                         0.000000e+00
# arrival_date_week_number                 6.653096e-199
# arrival_date_day_of_month                 3.667548e-05
# stays_in_weekend_nights                   1.361756e-80
# stays_in_week_nights                     1.429186e-102
# adults                                    1.624957e-35
# children                                  1.926419e-91
# babies                                    2.325218e-09
# previous_cancellations                    1.000000e+00
# previous_bookings_not_canceled           9.353028e-272
# booking_changes                          1.795610e-139
# agent                                     0.000000e+00
# days_in_waiting_list                      0.000000e+00
# adr                                       0.000000e+00
# required_car_parking_spaces               5.744722e-52
# total_of_special_requests                 0.000000e+00
# is_repeated_guest                         0.000000e+00
# reservation_status                        0.000000e+00
#
#                                 previous_bookings_not_canceled  \
# lead_time                                         0.000000e+00
# arrival_date_year                                 4.831966e-36
# arrival_date_week_number                          2.753100e-50
# arrival_date_day_of_month                         6.325156e-01
# stays_in_weekend_nights                          4.161439e-184
# stays_in_week_nights                              0.000000e+00
# adults                                            0.000000e+00
# children                                          4.785981e-34
# babies                                            1.234096e-04
# previous_cancellations                           9.353028e-272
# previous_bookings_not_canceled                    1.000000e+00
# booking_changes                                   2.943716e-26
# agent                                             0.000000e+00
# days_in_waiting_list                              7.068965e-11
# adr                                               0.000000e+00
# required_car_parking_spaces                      7.888014e-284
# total_of_special_requests                         5.291267e-18
# is_repeated_guest                                 0.000000e+00
# reservation_status                                0.000000e+00
#
#                                 booking_changes          agent  \
# lead_time                          7.099965e-03  6.490320e-123
# arrival_date_year                  6.678876e-15  1.182107e-163
# arrival_date_week_number           6.568161e-03   2.641127e-14
# arrival_date_day_of_month          1.708931e-05   6.908329e-01
# stays_in_weekend_nights            3.009400e-44   0.000000e+00
# stays_in_week_nights              3.409472e-110   0.000000e+00
# adults                            3.389177e-190  6.744590e-297
# children                          5.813284e-115   2.039453e-88
# babies                             0.000000e+00   1.712523e-20
# previous_cancellations            1.795610e-139   0.000000e+00
# previous_bookings_not_canceled     2.943716e-26   0.000000e+00
# booking_changes                    1.000000e+00   4.139732e-04
# agent                              4.139732e-04   1.000000e+00
# days_in_waiting_list               5.710443e-11   2.400773e-07
# adr                                7.182222e-02   2.229287e-92
# required_car_parking_spaces       4.685791e-151   1.381631e-83
# total_of_special_requests          1.359006e-47  2.486308e-201
# is_repeated_guest                  2.375606e-10   0.000000e+00
# reservation_status                 0.000000e+00   3.243741e-16
#
#                                 days_in_waiting_list            adr  \
# lead_time                               0.000000e+00   2.337740e-07
# arrival_date_year                      8.350292e-182   0.000000e+00
# arrival_date_week_number                2.222217e-01  3.057874e-143
# arrival_date_day_of_month               9.113989e-29   2.834528e-20
# stays_in_weekend_nights                1.696406e-147   1.624777e-70
# stays_in_week_nights                    4.948018e-05  2.448374e-231
# adults                                  1.515280e-36   0.000000e+00
# children                                4.747059e-62   0.000000e+00
# babies                                  1.077633e-06   1.952972e-19
# previous_cancellations                  0.000000e+00   0.000000e+00
# previous_bookings_not_canceled          7.068965e-11   0.000000e+00
# booking_changes                         5.710443e-11   7.182222e-02
# agent                                   2.400773e-07   2.229287e-92
# days_in_waiting_list                    1.000000e+00   1.650241e-42
# adr                                     1.650241e-42   1.000000e+00
# required_car_parking_spaces             6.836159e-51   1.309864e-29
# total_of_special_requests               0.000000e+00   0.000000e+00
# is_repeated_guest                       1.504577e-21   0.000000e+00
# reservation_status                     3.598093e-279   3.055598e-78
#
#                                 required_car_parking_spaces  \
# lead_time                                      0.000000e+00
# arrival_date_year                              1.724767e-08
# arrival_date_week_number                       2.775941e-01
# arrival_date_day_of_month                      3.327712e-03
# stays_in_weekend_nights                        1.242844e-10
# stays_in_week_nights                           1.253646e-31
# adults                                         5.957102e-10
# children                                       1.014928e-98
# babies                                         1.089780e-44
# previous_cancellations                         5.744722e-52
# previous_bookings_not_canceled                7.888014e-284
# booking_changes                               4.685791e-151
# agent                                          1.381631e-83
# days_in_waiting_list                           6.836159e-51
# adr                                            1.309864e-29
# required_car_parking_spaces                    1.000000e+00
# total_of_special_requests                     4.852002e-202
# is_repeated_guest                             1.045740e-149
# reservation_status                             0.000000e+00
#
#                                 total_of_special_requests  is_repeated_guest  \
# lead_time                                   8.008485e-145       0.000000e+00
# arrival_date_year                            0.000000e+00       3.405556e-04
# arrival_date_week_number                     4.722379e-11       8.792672e-26
# arrival_date_day_of_month                    2.798717e-01       3.535918e-02
# stays_in_weekend_nights                     3.446921e-166      8.441417e-248
# stays_in_week_nights                        2.412779e-153       0.000000e+00
# adults                                       0.000000e+00       0.000000e+00
# children                                    1.151627e-240       3.427546e-33
# babies                                      1.036371e-226       1.128033e-03
# previous_cancellations                       0.000000e+00       0.000000e+00
# previous_bookings_not_canceled               5.291267e-18       0.000000e+00
# booking_changes                              1.359006e-47       2.375606e-10
# agent                                       2.486308e-201       0.000000e+00
# days_in_waiting_list                         0.000000e+00       1.504577e-21
# adr                                          0.000000e+00       0.000000e+00
# required_car_parking_spaces                 4.852002e-202      1.045740e-149
# total_of_special_requests                    1.000000e+00       5.589279e-02
# is_repeated_guest                            5.589279e-02       1.000000e+00
# reservation_status                           0.000000e+00      4.566223e-189
#
#                                 reservation_status
# lead_time                             0.000000e+00
# arrival_date_year                     1.440063e-11
# arrival_date_week_number              7.261757e-08
# arrival_date_day_of_month             2.377855e-04
# stays_in_weekend_nights               9.891900e-03
# stays_in_week_nights                  5.898075e-56
# adults                               9.581359e-169
# children                              2.347799e-01
# babies                                6.549740e-31
# previous_cancellations                0.000000e+00
# previous_bookings_not_canceled        0.000000e+00
# booking_changes                       0.000000e+00
# agent                                 3.243741e-16
# days_in_waiting_list                 3.598093e-279
# adr                                   3.055598e-78
# required_car_parking_spaces           0.000000e+00
# total_of_special_requests             0.000000e+00
# is_repeated_guest                    4.566223e-189
# reservation_status                    1.000000e+00

# %% [markdown]
# #### NUM data - conclusion
# We can see with good confidence (very low p-val) that `lead_time` has strong correlation to the reservation status, along with additional `previous_cancellations` `booking_changes`, `required_car_parking_sapce`, `days_in_waiting_list`, and `total_special_requests`

# %% [markdown]
# #### Boolean data

# %%
sns.countplot(data=df, x='is_repeated_guest', hue='reservation_status');

# %%
df['is_room_type_changed'] = df['reserved_room_type'] == df['assigned_room_type']
bool_cols.append('is_room_type_changed')
sns.countplot(data=df, x='is_room_type_changed', hue='reservation_status');

# %%
df_bool = df.copy()[bool_cols]
df_bool['reservation_status'] = df['reservation_status'].astype('category').cat.codes
plot_heatmaps(df_bool, figsize=(6, 4))
# Out:
# ********************************************************************
#
# pearson
#
# correlations
#                       is_repeated_guest  is_room_type_changed  \
# is_repeated_guest              1.000000             -0.084158
# is_room_type_changed          -0.084158              1.000000
# reservation_status             0.083498             -0.246187
#
#                       reservation_status
# is_repeated_guest               0.083498
# is_room_type_changed           -0.246187
# reservation_status              1.000000
#
# p-value
#                       is_repeated_guest  is_room_type_changed  \
# is_repeated_guest          1.000000e+00         1.494877e-186
# is_room_type_changed      1.494877e-186          1.000000e+00
# reservation_status        1.170788e-183          0.000000e+00
#
#                       reservation_status
# is_repeated_guest          1.170788e-183
# is_room_type_changed        0.000000e+00
# reservation_status          1.000000e+00
# ********************************************************************
#
# spearman
#
# correlations
#                       is_repeated_guest  is_room_type_changed  \
# is_repeated_guest              1.000000             -0.084158
# is_room_type_changed          -0.084158              1.000000
# reservation_status             0.084728             -0.249425
#
#                       reservation_status
# is_repeated_guest               0.084728
# is_room_type_changed           -0.249425
# reservation_status              1.000000
#
# p-value
#                       is_repeated_guest  is_room_type_changed  \
# is_repeated_guest          1.000000e+00         1.494877e-186
# is_room_type_changed      1.494877e-186          1.000000e+00
# reservation_status        4.566223e-189          0.000000e+00
#
#                       reservation_status
# is_repeated_guest          4.566223e-189
# is_room_type_changed        0.000000e+00
# reservation_status          1.000000e+00

# %% [markdown]
# #### BOOL data - conclusion
# We can see with good confidence (very low p-val) that `is_room_type_changesd` has strong correlation to the reservation status, which is a new col we generated stating if there was a change is the room assigned for the visitor, in comparison to the initially reserved room type.

# %% [markdown]
# #### Time Series
# We try to look if there is any time-series signal that can be shown from the data. So we generate an `arrival_date` column and plot the `reservation_status` count for reservation that were to arrive that day

# %%
months = list(df.arrival_date_month.unique())
month_map = {months[i]: (i + 7) % 12 for i in range(0, 12)}
month_map['December'] = 12
df['arrival_date'] = df.apply(
    lambda row: pd.Timestamp(day=int(row.arrival_date_day_of_month), month=month_map[row.arrival_date_month],
                             year=int(row.arrival_date_year)), axis=1)

# %%
_, ax = plt.subplots(1, 1, figsize=(15, 10))
ax.set(title='reservation_status density plot by the reservation\'s expected arrival_date')
sns.histplot(data=df, x='arrival_date', hue='reservation_status', bins=60, ax=ax, stat='density', element='step',
             kde=True);

# %% [markdown]
# There is some seasonality with respect to the reservation status, yet it seems more likely because of the total seasonal demand for hotel rooms, while we can see the the difference between the 3 `reservation_type` population remains similar throughout the timeline
# We infer though that there is not strong signal here for label prediction

# %% [markdown]
# Next, we plot 2 of the most correlated features with the target label: `lead_time` and `deposit_type`

# %%
_, ax = plt.subplots(1, 1, figsize=(15, 7))
sns.violinplot(data=df, x='deposit_type', y='lead_time', hue='reservation_status', ax=ax, inner='point')
ax.set(
    title=f'reservation_status signal according to deposit_type and lead_time',
    xlabel=f'deposit_type:\n\n{columns_mapping["deposit_type"]}',
    ylabel=f'lead_time:\n\n{columns_mapping["lead_time"]}'
);

# %% [markdown]
# This shows some very interesting results:
# 1. It seems that the majority of the `Non Refund` deposit type population had chosen to cancel its reservation - very surprising!
# 2. It looks like `Non Refund` also usually also involves a land leading time between the reservation data and the actual arrival data
# 3. Short `lead_time` are more common with `No Deposit` deposit population, and we do see that in general the shorter the lead, the less likely a reservation get canceled
# 4. We do not see any siginificant difference in the `Refundable` group. This can imply that `Refundable` deposits have little significance for CO/Cancellation, but does imply it is less likely to `No Show`

# %% [markdown]
# ## Modeling

# %%
RANDOM_STATE = 42

# %%
def _generate_train_test(X, y):
    cat_cols = [
        'deposit_type',
        'market_segment',
        'assigned_room_type',
        'country',
        'hotel',
        'distribution_channel',
        'is_room_type_changed'
    ]

    X = X[
        [
            'lead_time',
            'booking_changes',
            'previous_cancellations',
            'previous_bookings_not_canceled',
            'days_in_waiting_list',
            'total_of_special_requests',
            'required_car_parking_spaces',
        ] + cat_cols
        ]

    for col in cat_cols:
        X[col] = X[col].astype('category').cat.codes

    return train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

# %%
def run_simulation(algo, iter_num, X, y, hyperparam, cv=3, **kwargs) -> list:
    scores = []
    for i in range(1, iter_num + 1):
        kwargs[hyperparam] = i
        model = algo(random_state=RANDOM_STATE, **kwargs)
        scores.append(np.mean(cross_val_score(model, X, y, cv=cv)))
    _, ax = plt.subplots(1, 1, figsize=(12, 7))
    sns.lineplot(y=scores, x=range(len(scores)), ax=ax)
    ax.set(title=f'{algo.__name__} training by {hyperparam} tweaking', xlabel=hyperparam, ylabel='Accuracy')
    return scores

# %%
def get_best_score(scores):
    best_score = max(scores)
    best_hyperparam = scores.index(best_score) + 1
    print(f'Achieved best score of {best_score} for iteration {best_hyperparam}')
    return best_hyperparam

# %%
def get_sorted_feature_importance(model):
    features_dict = {model.feature_names_in_[i]: model.feature_importances_[i] for i in range(model.n_features_in_)}
    return pd.Series({k: v for k, v in sorted(features_dict.items(), key=lambda item: item[1], reverse=True)})

# %%
def plot_norm_conf_matrix(fitted_model, X, y, normalize='true'):
    _, ax = plt.subplots(1, 1, figsize=(12, 7))
    ConfusionMatrixDisplay.from_estimator(estimator=fitted_model, X=X, y=y, normalize=normalize, ax=ax)
    ax.set(
        title=f'{fitted_model.__class__.__name__} test set confusion matrix\nnormalized over the {normalize} conditions');

# %%
def calc_metrics(model, X, y):
    metrics = precision_recall_fscore_support(y_true=y, y_pred=model.predict(X))
    return pd.DataFrame(metrics, index=['precision', 'recall', 'fscore', 'support'],
                        columns=['Canceled', 'Check-Out', 'No-Show']).T

# %%
def generate_train_test(df):
    X: pd.DataFrame = df.copy()
    y = X.pop('reservation_status')
    return _generate_train_test(X, y)

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### In the following code, we trained a DecisionTreeClassifier and exhibit the next:
# 1. We see the overfitting tendency of decision trees by running a k-fold cross-validation training simulation and tweaking the `max-dpeth` param.
# 2. Then, chose the best hyperparam according to the model accuracy on the test set, and trained a classifier
# 3. For sanity, we print out the feature importance given by the fitted model, and as expected, the `deposit_type` and `lead_time` features were very correlative with the label
# 4. We the printed out the confusion matrix, normalized by the predictions conditions, since business-wise we thought that precision is more important for hotel owners (hotel managers might want to take actions when the model predicts a cancellation or a No-Show, thus thus predictions should not have high False-Positive)
# 5. We do see that model scores are effected by the fact that the dataset is unbalanced, since most No-Shows are with zero deposit fee, we next train another model, after resampling the data to achive a balanced classed training set

# %%
x_train, x_test, y_train, y_test = generate_train_test(df)

# %%
scores = run_simulation(
    algo=DecisionTreeClassifier,
    iter_num=25,
    hyperparam='max_depth',
    criterion='entropy',
    X=x_train,
    y=y_train
)

# %%
best_hyper_param = get_best_score(scores)
# Out:
# Achieved best score of 0.8342442517904258 for iteration 13

# %%
dtm = DecisionTreeClassifier(criterion='entropy', max_depth=best_hyper_param, random_state=RANDOM_STATE)
dtm.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=13, random_state=42)

# %%
print(get_sorted_feature_importance(dtm))
# Out:
# deposit_type                      0.368371
# market_segment                    0.128353
# lead_time                         0.113739
# country                           0.098365
# is_room_type_changed              0.075570
# total_of_special_requests         0.063554
# required_car_parking_spaces       0.050115
# previous_cancellations            0.039087
# booking_changes                   0.021195
# previous_bookings_not_canceled    0.012009
# hotel                             0.011899
# assigned_room_type                0.008700
# distribution_channel              0.006021
# days_in_waiting_list              0.003022
# dtype: float64

# %%
print(f'model test score = {dtm.score(x_test, y_test)}')
# Out:
# model test score = 0.837716726694028

# %%
plot_norm_conf_matrix(fitted_model=dtm, X=x_test, y=y_test)

# %%
calc_metrics(dtm, X=x_test, y=y_test)
# Out:
#            precision    recall    fscore  support
# Canceled    0.797055  0.767554  0.782026   8673.0
# Check-Out   0.860656  0.890603  0.875373  14973.0
# No-Show     0.343750  0.047414  0.083333    232.0

# %% [markdown]
# #### Decision Tree with Balanced Sampling

# %% [markdown]
# We over/under sample the label population by Bootstrapping
# We can see that by oversampling randomly, we manged to get a much better recall score over the No-Show population, although it reduced the overall accuracy of the model
# Under-sampling didn't go well (probably the loss of the majority of samples caused the signal to weakened
# So, we would choose to **oversample** the data in the next modeling phases if we are to gain a higher recall for No-Show population

# %% [markdown]
# **Over sampling**

# %%
x_train, x_test, y_train, y_test = generate_train_test(df)
over_sampler = RandomOverSampler()
x_train, y_train = over_sampler.fit_resample(x_train, y_train)

# %%
y_train.value_counts() / y_train.shape[0]
# Out:
# Canceled     0.333333
# Check-Out    0.333333
# No-Show      0.333333
# Name: reservation_status, dtype: float64

# %%
y_test.value_counts() / y_test.shape[0]
# Out:
# Check-Out    0.627063
# Canceled     0.363221
# No-Show      0.009716
# Name: reservation_status, dtype: float64

# %%
scores = run_simulation(
    algo=DecisionTreeClassifier,
    iter_num=30,
    hyperparam='max_depth',
    criterion='entropy',
    X=x_train,
    y=y_train
)

# %%
best_hyper_param = get_best_score(scores)
# Out:
# Achieved best score of 0.8980723118413548 for iteration 30

# %%
dtm = DecisionTreeClassifier(criterion='entropy', max_depth=best_hyper_param, random_state=RANDOM_STATE)
dtm.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=30, random_state=42)

# %%
print(f'model test score = {dtm.score(x_test, y_test)}')
# Out:
# model test score = 0.8050087947064243

# %%
plot_norm_conf_matrix(fitted_model=dtm, X=x_test, y=y_test)

# %%
calc_metrics(dtm, X=x_test, y=y_test)
# Out:
#            precision    recall    fscore  support
# Canceled    0.755086  0.791652  0.772937   8673.0
# Check-Out   0.881538  0.820544  0.849948  14973.0
# No-Show     0.082547  0.301724  0.129630    232.0

# %% [markdown]
# **Under sampling**

# %%
x_train, x_test, y_train, y_test = generate_train_test(df)
under_sampler = RandomUnderSampler()
x_train, y_train = under_sampler.fit_resample(x_train, y_train)

# %%
y_train.value_counts() / y_train.shape[0]
# Out:
# Canceled     0.333333
# Check-Out    0.333333
# No-Show      0.333333
# Name: reservation_status, dtype: float64

# %%
y_test.value_counts() / y_test.shape[0]
# Out:
# Check-Out    0.627063
# Canceled     0.363221
# No-Show      0.009716
# Name: reservation_status, dtype: float64

# %%
scores = run_simulation(
    algo=DecisionTreeClassifier,
    iter_num=50,
    hyperparam='max_depth',
    criterion='entropy',
    X=x_train,
    y=y_train
)

# %%
best_hyper_param = get_best_score(scores)
# Out:
# Achieved best score of 0.6379487179487179 for iteration 8

# %%
dtm = DecisionTreeClassifier(criterion='entropy', max_depth=best_hyper_param, random_state=RANDOM_STATE)
dtm.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, random_state=42)

# %%
print(f'model test score = {dtm.score(x_test, y_test)}')
# Out:
# model test score = 0.6479604657006449

# %%
plot_norm_conf_matrix(fitted_model=dtm, X=x_test, y=y_test)

# %%
calc_metrics(dtm, X=x_test, y=y_test)
# Out:
#            precision    recall    fscore  support
# Canceled    0.779417  0.694223  0.734358   8673.0
# Check-Out   0.865724  0.621786  0.723753  14973.0
# No-Show     0.026116  0.607759  0.050080    232.0

# %% [markdown]
# ### Random Forest

# %% [markdown]
# We can see that for Random Forest, there is no overfitting when increasing the number of estimators
# The classifier also seems to present better results to the singleton decision tree, although it uses much less complex trees for bagging (20 depth)

# %%
x_train, x_test, y_train, y_test = generate_train_test(df)

# %%
scores = run_simulation(
    algo=RandomForestClassifier,
    iter_num=30,
    hyperparam='n_estimators',
    criterion='entropy',
    max_depth=20,
    X=x_train,
    y=y_train
)

# %%
best_hyper_param = get_best_score(scores)
# Out:
# Achieved best score of 0.8471855760773966 for iteration 29

# %%
rfm = RandomForestClassifier(
    criterion='entropy',
    random_state=RANDOM_STATE,
    n_estimators=best_hyper_param,
    max_depth=20
)
rfm.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=20, n_estimators=29,
#                        random_state=42)

# %%
print(get_sorted_feature_importance(rfm))
# Out:
# lead_time                         0.211809
# deposit_type                      0.173366
# country                           0.166053
# market_segment                    0.108716
# total_of_special_requests         0.068176
# is_room_type_changed              0.061455
# previous_cancellations            0.043346
# required_car_parking_spaces       0.042629
# assigned_room_type                0.036590
# booking_changes                   0.031931
# distribution_channel              0.020534
# hotel                             0.016858
# previous_bookings_not_canceled    0.012414
# days_in_waiting_list              0.006124
# dtype: float64

# %%
print(f'model test score = {rfm.score(x_test, y_test)}')
# Out:
# model test score = 0.8519976547449535

# %%
plot_norm_conf_matrix(fitted_model=rfm, X=x_test, y=y_test, normalize='true')

# %%
calc_metrics(rfm, X=x_test, y=y_test)
# Out:
#            precision    recall    fscore  support
# Canceled    0.821996  0.781621  0.801300   8673.0
# Check-Out   0.869216  0.904628  0.886569  14973.0
# No-Show     0.416667  0.086207  0.142857    232.0

# %% [markdown]
# ### ADABoosting

# %% [markdown]
# We can see that for ADABoost, there is overfitting when increasing the number of estimators
# The classifier also seems to presents worse results than the Random Forest one.
# Converge time is much better than in the Gradient Boosting classifier

# %%
x_train, x_test, y_train, y_test = generate_train_test(df)

# %%
scores = run_simulation(
    algo=AdaBoostClassifier,
    iter_num=30,
    base_estimator=DecisionTreeClassifier(max_depth=1),
    hyperparam='n_estimators',
    X=x_train,
    y=y_train
)

# %%
best_hyper_param = get_best_score(scores)
# Out:
# Achieved best score of 0.8259936340411275 for iteration 19

# %%
abm = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1), n_estimators=best_hyper_param)
abm.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
#                    n_estimators=19)

# %%
print(get_sorted_feature_importance(abm))
# Out:
# country                           0.315789
# lead_time                         0.157895
# deposit_type                      0.105263
# booking_changes                   0.052632
# previous_cancellations            0.052632
# previous_bookings_not_canceled    0.052632
# total_of_special_requests         0.052632
# required_car_parking_spaces       0.052632
# market_segment                    0.052632
# hotel                             0.052632
# is_room_type_changed              0.052632
# days_in_waiting_list              0.000000
# assigned_room_type                0.000000
# distribution_channel              0.000000
# dtype: float64

# %%
print(f'model test score = {abm.score(x_test, y_test)}')
# Out:
# model test score = 0.8282938269536813

# %%
plot_norm_conf_matrix(fitted_model=abm, X=x_test, y=y_test, normalize='true')

# %%
calc_metrics(abm, X=x_test, y=y_test)
# Out:
#            precision    recall    fscore  support
# Canceled    0.800330  0.727891  0.762394   8673.0
# Check-Out   0.842089  0.899285  0.869748  14973.0
# No-Show     0.000000  0.000000  0.000000    232.0

# %% [markdown]
# ### Gradient Boosting

# %% [markdown]
# We can see that for Gradient Boost, there is overfitting when increasing the number of estimators
# The classifier also seems to present slightly worse results than the Random Forest one and than ADA Boost.
# Converge time is very long

# %%
x_train, x_test, y_train, y_test = generate_train_test(df)

# %%
scores = run_simulation(
    algo=GradientBoostingClassifier,
    iter_num=30,
    hyperparam='n_estimators',
    init=DecisionTreeClassifier(max_depth=2),
    X=x_train,
    y=y_train,
    cv=2
)

# %%
best_hyper_param = get_best_score(scores)
# Out:
# Achieved best score of 0.8261611592746158 for iteration 30

# %%
gbm = GradientBoostingClassifier(n_estimators=best_hyper_param, init=DecisionTreeClassifier(max_depth=1))
gbm.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(init=DecisionTreeClassifier(max_depth=1),
#                            n_estimators=30)

# %%
print(get_sorted_feature_importance(gbm))
# Out:
# market_segment                    0.226300
# country                           0.165263
# lead_time                         0.160868
# is_room_type_changed              0.119097
# total_of_special_requests         0.111344
# required_car_parking_spaces       0.075196
# previous_cancellations            0.043736
# deposit_type                      0.038872
# booking_changes                   0.029204
# previous_bookings_not_canceled    0.028258
# assigned_room_type                0.001783
# hotel                             0.000076
# distribution_channel              0.000004
# days_in_waiting_list              0.000000
# dtype: float64

# %%
print(f'model test score = {gbm.score(x_test, y_test)}')
# Out:
# model test score = 0.8185777703325237

# %%
plot_norm_conf_matrix(fitted_model=gbm, X=x_test, y=y_test)

# %%
calc_metrics(gbm, X=x_test, y=y_test)
# Out:
#            precision    recall    fscore  support
# Canceled    0.831114  0.654791  0.732491   8673.0
# Check-Out   0.813552  0.926134  0.866200  14973.0
# No-Show     0.000000  0.000000  0.000000    232.0
